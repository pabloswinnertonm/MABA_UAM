# %% [markdown]
# ## **MiniLab_01**

# %%
df = spark.table('workspace.sesion_07.retail_transactions_course_dataset')

# %%
display(df)

# %% [markdown]
# ## **MiniLab_02**

# %%
df_clean = df

# %%
df_clean = df_clean.dropDuplicates(["transaction_id"])

# %%
df_clean = df_clean.dropna(subset=["transaction_id", "transaction_ts", "total_eur"])

# %%
display(df_clean)

# %%
df_clean.count()

# %%
df_clean.describe()

# %%
df_clean.printSchema()

# %% [markdown]
# ### **Delta Lake Versioning Example**

# %%
df_clean.write.format("delta").mode("overwrite").saveAsTable("retail_delta")

# %%
# %sql
UPDATE retail_delta
SET discount_pct = '0'
WHERE discount_pct = 'N/A';
